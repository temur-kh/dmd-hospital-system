# %% [markdown]
# # Firebase Demo

# %%
import firebase_admin
from firebase_admin import credentials
from firebase_admin import firestore
import pandas as pd
from pprint import pprint
from IPython.display import display
pd.set_option('display.max_columns', None)
pd.set_option('max_colwidth', 1000)

# %% [markdown]
# ### establishing connection

# %%
def establish_creds():
#     you need credentials file
    cred = credentials.Certificate('cred.json')
    firebase_admin.initialize_app(cred)
establish_creds()

# %%
db = firestore.client()

# %% [markdown]
# ### read a collection

# %%
def print_doc(doc):
    d = doc.to_dict()
    df = pd.DataFrame([d], index=[doc.id])
    display(df)

def print_docs(docs):
    for doc in docs:
        print_doc(doc)

def print_dict(doc):
    pprint(doc.to_dict())

def print_dicts(docs):
    for doc in docs:
        print_dict(doc)

# %%
users_ref = db.collection("employees").limit(5)
docs = users_ref.stream()
print_docs(docs)
# Out:
#                                                              address  \
# 0DKu7oIWmNibuW80AXy1  18459 Johnson Haven\nSouth Stephanie, NY 70923
#
#                            contactNumber gender          name   role  salary
# 0DKu7oIWmNibuW80AXy1  797.068.2595x62393      M  James Barnes  nurse   17540
#                                                             address  \
# 0Dnw3tOd3FrnPRUNZbUu  300 Brown Mews Apt. 012\nNorth Ryan, ME 90964
#
#                      contactNumber gender           name    role  salary  \
# 0Dnw3tOd3FrnPRUNZbUu  898.180.7691      F  Amanda Murphy  doctor   31600
#
#                          status
# 0Dnw3tOd3FrnPRUNZbUu  permanent
#                                                                      address  \
# 0FJVjirro8ehObVMp4NB  7798 Parker Turnpike Apt. 223\nWest Jennifer, AL 32862
#
#                       contactNumber gender         name    role  salary  \
# 0FJVjirro8ehObVMp4NB  (138)796-0864      M  James Scott  doctor   27210
#
#                          status
# 0FJVjirro8ehObVMp4NB  permanent
#                                                        address  \
# 0Q2uajUrTnjy7GrnyjsL  548 Walter Springs\nNorth Mark, AK 99647
#
#                              contactNumber gender                name  \
# 0Q2uajUrTnjy7GrnyjsL  +1-379-356-2954x8517      F  Mrs. Pamela Watson
#
#                             role  salary
# 0Q2uajUrTnjy7GrnyjsL  pharmacist   16590
#                                                               address  \
# 0QrhT2RErKsvSVzjDzj9  821 Wheeler Trafficway\nLake Jennifer, AK 18945
#
#                      contactNumber gender            name   role  salary
# 0QrhT2RErKsvSVzjDzj9  006-382-7945      F  Vanessa Knight  nurse   19450

# %% [markdown]
# ### read a document with a specific id

# %%
doc_ref = db.collection("employees").document("0DKu7oIWmNibuW80AXy1")
doc = doc_ref.get()
print_doc(doc)
# Out:
#                                                              address  \
# 0DKu7oIWmNibuW80AXy1  18459 Johnson Haven\nSouth Stephanie, NY 70923
#
#                            contactNumber gender          name   role  salary
# 0DKu7oIWmNibuW80AXy1  797.068.2595x62393      M  James Barnes  nurse   17540

# %% [markdown]
# ### insert a document

# %%
new_employee = {
    'address': 'Innopolis',
    'contractNumber': '+98765432101',
    'gender': 'M',
    'name': 'Rishat Maksudov',
    'role': 'Nurse',
    'salary': 12000,
}

new_em_ref = db.collection('employees').document()
new_em_ref.set(new_employee)
# Out:
# update_time {
#   seconds: 1556191948
#   nanos: 673407000
# }

# %%
def find_rishat():
    refs = db.collection('employees').where('name', '==', 'Rishat Maksudov')
    for doc in refs.stream():
        print_doc(doc)
        break

find_rishat()
# Out:
#                         address contractNumber gender             name   role  \
# vXW1YIF1lyAcAX9mYwHC  Innopolis   +98765432101      M  Rishat Maksudov  Nurse
#
#                       salary
# vXW1YIF1lyAcAX9mYwHC   12000

# %% [markdown]
# ### update the previously inserted document

# %%
new_em_ref.update({
    'role': 'Doctor',
    'status': 'intern',
    'salary': 18000,
})
# Out:
# update_time {
#   seconds: 1556191957
#   nanos: 499546000
# }

# %%
find_rishat()
# Out:
#                         address contractNumber gender             name  \
# vXW1YIF1lyAcAX9mYwHC  Innopolis   +98765432101      M  Rishat Maksudov
#
#                         role  salary  status
# vXW1YIF1lyAcAX9mYwHC  Doctor   18000  intern

# %%
new_em_ref.delete()
# Out:
# seconds: 1556191965
# nanos: 853433000

# %%
find_rishat()

# %% [markdown]
# ### order and limit

# %%
docs = db.collection('medicines').order_by('name').limit(3).stream()
print_docs(docs)
# Out:
#                                        expDate      name  price quantity  sold
# 1jHLHpmAmJZ1UfIVbFi3 2019-05-01 08:36:06+00:00  Abakavir   1500    81 ml  True
#                                        expDate      name  price quantity  sold
# 3ilXqcmkf1uY8yM8Zvc8 2019-05-18 05:49:21+00:00  Abakavir   1500    78 ml  True
#                                        expDate      name  price    quantity  \
# 3jRs2GMFzGiQHMU6OoSs 2019-06-04 00:12:07+00:00  Abakavir   1500  70 unit(s)
#
#                       sold
# 3jRs2GMFzGiQHMU6OoSs  True

# %% [markdown]
# ### perform simple queries

# %%
query = db.collection("medicines").limit(20).where('price', '>', 120)
docs = query.stream()
print_docs(docs)
# Out:
#                                        expDate       name  price    quantity  \
# 00nNm1AHy5uABtaPKjQO 2019-06-07 08:20:22+00:00  Klemastin    140  41 unit(s)
#
#                       sold
# 00nNm1AHy5uABtaPKjQO  True
#                                        expDate       name  price    quantity  \
# 1qSzppusHKluXeVQqojR 2019-05-31 13:05:27+00:00  Klemastin    140  55 unit(s)
#
#                       sold
# 1qSzppusHKluXeVQqojR  True
#                                        expDate       name  price    quantity  \
# 2GiCOcGPx6xe7uFMqTao 2019-08-19 00:22:06+00:00  Klemastin    140  76 unit(s)
#
#                       sold
# 2GiCOcGPx6xe7uFMqTao  True
#                                        expDate       name  price    quantity  \
# 3QJnOWmO0dWdCy0hX9nJ 2019-07-02 14:18:58+00:00  Klemastin    140  92 unit(s)
#
#                       sold
# 3QJnOWmO0dWdCy0hX9nJ  True
#                                        expDate       name  price    quantity  \
# 3umXOkbzEribdfIWlz5h 2019-06-27 21:00:45+00:00  Klemastin    140  81 unit(s)
#
#                       sold
# 3umXOkbzEribdfIWlz5h  True
#                                        expDate       name  price    quantity  \
# 7RRj9tTUI85YdlLNEZMV 2019-05-07 10:15:05+00:00  Klemastin    140  57 unit(s)
#
#                       sold
# 7RRj9tTUI85YdlLNEZMV  True
#                                        expDate       name  price quantity  \
# 9tnx2KgSTyY91vxnawYu 2019-07-30 04:38:35+00:00  Klemastin    140    16 ml
#
#                       sold
# 9tnx2KgSTyY91vxnawYu  True
#                                        expDate       name  price quantity  \
# BFODon8lOy4PVRGbNzLW 2019-05-02 19:06:28+00:00  Klemastin    140    33 ml
#
#                       sold
# BFODon8lOy4PVRGbNzLW  True
#                                        expDate       name  price    quantity  \
# DAFJkcxLo4bhbU5NA3eM 2019-06-28 06:14:59+00:00  Klemastin    140  41 unit(s)
#
#                       sold
# DAFJkcxLo4bhbU5NA3eM  True
#                                        expDate       name  price    quantity  \
# DkjyyU25SChIHsSi3tcR 2019-06-21 19:20:39+00:00  Klemastin    140  16 unit(s)
#
#                       sold
# DkjyyU25SChIHsSi3tcR  True
#                                        expDate       name  price    quantity  \
# EIM9Irx12dYlxoGtTFAF 2019-07-31 18:16:07+00:00  Klemastin    140  97 unit(s)
#
#                       sold
# EIM9Irx12dYlxoGtTFAF  True
#                                        expDate       name  price    quantity  \
# F4xd0Ew4vBNMbftgTWPO 2019-07-29 15:26:27+00:00  Klemastin    140  88 unit(s)
#
#                       sold
# F4xd0Ew4vBNMbftgTWPO  True
#                                        expDate       name  price quantity  \
# LIeBQSQGFxai0aVrDa2S 2019-07-01 15:15:19+00:00  Klemastin    140    72 ml
#
#                       sold
# LIeBQSQGFxai0aVrDa2S  True
#                                        expDate       name  price quantity  \
# PIh1o2dK37vEaLH2x59Q 2019-05-03 18:44:48+00:00  Klemastin    140    42 ml
#
#                       sold
# PIh1o2dK37vEaLH2x59Q  True
#                                        expDate       name  price    quantity  \
# PYexlbsmcC58SxypJqUO 2019-06-14 18:43:36+00:00  Klemastin    140  92 unit(s)
#
#                       sold
# PYexlbsmcC58SxypJqUO  True
#                                        expDate       name  price quantity  \
# PjNxOOjZxiHPQ5P3pIGu 2019-05-02 13:42:44+00:00  Klemastin    140    73 ml
#
#                       sold
# PjNxOOjZxiHPQ5P3pIGu  True
#                                        expDate       name  price quantity  \
# SH0DInSPcRWgnRw5Oalc 2019-07-28 01:24:24+00:00  Klemastin    140    74 ml
#
#                       sold
# SH0DInSPcRWgnRw5Oalc  True
#                                        expDate       name  price quantity  \
# TBfQRbhLGq7eeHFZxUAA 2019-08-13 23:12:59+00:00  Klemastin    140    30 ml
#
#                        sold
# TBfQRbhLGq7eeHFZxUAA  False
#                                        expDate       name  price    quantity  \
# VxiFubcPxNwC8tc5iDYC 2019-06-11 18:46:14+00:00  Klemastin    140  87 unit(s)
#
#                        sold
# VxiFubcPxNwC8tc5iDYC  False
#                                        expDate       name  price    quantity  \
# W5dScAj5UiNb7Cw9UHjz 2019-06-06 18:27:57+00:00  Klemastin    140  89 unit(s)
#
#                       sold
# W5dScAj5UiNb7Cw9UHjz  True

# %% [markdown]
# ### let's face reference fields

# %%
query = db.collection("prescriptions").limit(1)
docs = query.stream()
print_docs(docs)
# Out:
#                                                                                                   bills  \
# 052OohKhqGPSTPiuKuXn  [<google.cloud.firestore_v1.document.DocumentReference object at 0x7fd92df4e828>]
#
#                                           date  \
# 052OohKhqGPSTPiuKuXn 2018-11-08 12:58:28+00:00
#
#                                                                                                                 description  \
# 052OohKhqGPSTPiuKuXn  Thought Republican officer beautiful likely game leg. Night all herself ground action take him along.
#
#                                                                                                doctor  \
# 052OohKhqGPSTPiuKuXn  <google.cloud.firestore_v1.document.DocumentReference object at 0x7fd92df4e438>
#
#                                                                                                                                                                                                   medList  \
# 052OohKhqGPSTPiuKuXn  [{'name': 'Nosh-pa', 'quantity': '44 unit(s)', 'price': 320}, {'name': 'Apap', 'quantity': '22 unit(s)', 'price': 35}, {'name': 'Trimoll', 'quantity': '66 unit(s)', 'price': 350}]
#
#                                                                                               patient
# 052OohKhqGPSTPiuKuXn  <google.cloud.firestore_v1.document.DocumentReference object at 0x7fd92df4e940>

# %% [markdown]
# ### kind of a join operation
#
#     SELECT patient FROM patient AS pat
#                    JOIN treatments AS tr ON pat=tr.patient

# %%
# query treatments
query = db.collection("prescriptions").limit(5)
docs = query.stream()
for doc in docs:
    patient_ref = doc.to_dict()['patient']
    # query patients independently
    patient_doc = patient_ref.get()
    print_doc(patient_doc)
# Out:
#                                                               address  \
# 6kyqkiV6DwiqqTvsprR4  384 Gutierrez Harbor\nNew Timothyland, TN 77661
#
#                           contactNumber             email gender  \
# 6kyqkiV6DwiqqTvsprR4  045-978-1117x8674  lreyes@yahoo.com      F
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          medHistory  \
# 6kyqkiV6DwiqqTvsprR4  [{'date': 2018-03-14 04:18:56+00:00, 'note': 'Have street go prepare. Real strong rise reflect. Cell nation among employee create.', 'prescription': None}, {'prescription': None, 'note': 'Rest evidence sign statement between. Reach build wrong run bit research.', 'date': 2018-09-14 22:02:56+00:00}, {'prescription': None, 'date': 2018-08-09 06:24:20+00:00, 'note': 'Couple truth big. Rule smile organization low Republican. Author sing evening green address measure others.'}]
#
#                               name
# 6kyqkiV6DwiqqTvsprR4  Debra Palmer
#                                                            address  \
# tgx7CuSSBEMZPBTGtDby  4250 Robert Heights\nEast Nicholas, SD 64892
#
#                      contactNumber                      email gender  \
# tgx7CuSSBEMZPBTGtDby  372-537-2917  calvinwhitehead@gmail.com      M
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                medHistory  \
# tgx7CuSSBEMZPBTGtDby  [{'prescription': None, 'note': 'Cover conference economy blood garden happy listen. Fish involve force product choose lot wind data. Bed matter suffer reduce administration admit media.', 'date': 2018-11-03 16:25:49+00:00}, {'note': 'Learn low here fly. Hold animal affect whether. Avoid claim detail small letter idea trouble.', 'date': 2018-06-20 17:51:14+00:00, 'prescription': None}, {'date': 2018-10-03 11:15:32+00:00, 'note': 'Care traditional deal require field themselves. Create learn film kind foot.', 'prescription': None}, {'prescription': None, 'date': 2018-08-10 03:15:31+00:00, 'note': 'Morning full sing. Situation right owner teacher cover fish ok take. Scientist evidence that degree good story others.'}, {'note': 'Appear dinner TV enough which section. Describe yes test happen defense.', 'date': 2018-06-03 22:05:28+00:00, 'prescription': None}]
#
#                                name
# tgx7CuSSBEMZPBTGtDby  Sean Fletcher
#                                                                        address  \
# KhcbfcrudC8w9CH0e1zV  926 Martinez Corner Suite 879\nEast Ashleyland, IA 54704
#
#                      contactNumber                    email gender  \
# KhcbfcrudC8w9CH0e1zV  457.394.3462  cynthiawalker@yahoo.com      F
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            medHistory  \
# KhcbfcrudC8w9CH0e1zV  [{'prescription': None, 'date': 2018-04-21 13:33:28+00:00, 'note': 'Situation glass east here one hope. Traditional attack civil peace.'}, {'prescription': None, 'note': 'Page team common million. Color line security difficult sure. Focus strong image everyone clearly its culture world. Film season improve million city difference marriage tough.', 'date': 2018-06-09 04:46:07+00:00}, {'date': 2018-05-13 03:39:35+00:00, 'note': 'Around man memory maintain television. Guy source here real food money.', 'prescription': None}]
#
#                                 name
# KhcbfcrudC8w9CH0e1zV  Rebecca Guzman
#                                                                        address  \
# 6dBvBH1DBjqcEQXlmylU  65032 Jose Radial Apt. 274\nSouth Brittanytown, WY 44169
#
#                      contactNumber                email gender  \
# 6dBvBH1DBjqcEQXlmylU  497-346-6088  cindywood@gmail.com      M
#
#                                                                                                                            medHistory  \
# 6dBvBH1DBjqcEQXlmylU  [{'date': 2018-09-12 21:10:51+00:00, 'note': 'Car out give. Summer pick over must old.', 'prescription': None}]
#
#                                name
# 6dBvBH1DBjqcEQXlmylU  Jordan Martin
#                                                                  address  \
# fdzm19h0BxGXGr20HTAI  2613 Adams Locks Suite 144\nSouth Dillon, UT 09372
#
#                             contactNumber               email gender  \
# fdzm19h0BxGXGr20HTAI  +1-176-621-9713x514  rachel50@yahoo.com      F
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         medHistory  \
# fdzm19h0BxGXGr20HTAI  [{'date': 2018-06-02 00:25:26+00:00, 'note': 'Development various value heavy history walk. Sea nearly through at factor.', 'prescription': None}, {'prescription': None, 'note': 'Physical blue goal like eat discuss to. Get start data final within. Heart money notice entire.', 'date': 2018-05-05 19:43:05+00:00}, {'note': 'Cultural just something brother himself. During collection check term bag off. Treatment measure minute rich.', 'date': 2018-09-22 08:56:36+00:00, 'prescription': None}]
#
#                                 name
# fdzm19h0BxGXGr20HTAI  Mckenzie Smith

# %% [markdown]
# ### perform compound queries (+contraints)
# You can also chain multiple where() methods to create more specific queries (logical AND). However, to combine the equality operator (==) with a range or array-contains clause (<, <=, >, >=, or array_contains), make sure to create a composite index.

# %%
# P.S. it should fail
patient_ref = db.collection("patients").limit(10).where('gender', '==', 'M').where('email', '<', 'f')
docs = patient_ref.stream()
print_docs(docs)
# Out:
# ---------------------------------------------------------------------------
# _Rendezvous                               Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/google/api_core/grpc_helpers.py in next(self)
#      78         try:
# ---> 79             return six.next(self._wrapped)
#      80         except grpc.RpcError as exc:
#
# ~/anaconda3/lib/python3.6/site-packages/grpc/_channel.py in __next__(self)
#     362     def __next__(self):
# --> 363         return self._next()
#     364
#
# ~/anaconda3/lib/python3.6/site-packages/grpc/_channel.py in _next(self)
#     356                     elif self._state.code is not None:
# --> 357                         raise self
#     358
#
# _Rendezvous: <_Rendezvous of RPC that terminated with:
# 	status = StatusCode.FAILED_PRECONDITION
# 	details = "The query requires an index. You can create it here: https://console.firebase.google.com/project/dmd-hospital-system/database/firestore/indexes?create_composite=ClRwcm9qZWN0cy9kbWQtaG9zcGl0YWwtc3lzdGVtL2RhdGFiYXNlcy8oZGVmYXVsdCkvY29sbGVjdGlvbkdyb3Vwcy9wYXRpZW50cy9pbmRleGVzL18QARoKCgZnZW5kZXIQARoJCgVlbWFpbBABGgwKCF9fbmFtZV9fEAE"
# 	debug_error_string = "{"created":"@1556190186.241304697","description":"Error received from peer ipv4:64.233.164.95:443","file":"src/core/lib/surface/call.cc","file_line":1041,"grpc_message":"The query requires an index. You can create it here: https://console.firebase.google.com/project/dmd-hospital-system/database/firestore/indexes?create_composite=ClRwcm9qZWN0cy9kbWQtaG9zcGl0YWwtc3lzdGVtL2RhdGFiYXNlcy8oZGVmYXVsdCkvY29sbGVjdGlvbkdyb3Vwcy9wYXRpZW50cy9pbmRleGVzL18QARoKCgZnZW5kZXIQARoJCgVlbWFpbBABGgwKCF9fbmFtZV9fEAE","grpc_status":9}"
# >
#
# The above exception was the direct cause of the following exception:
#
# FailedPrecondition                        Traceback (most recent call last)
# <ipython-input-19-85ae0807bd36> in <module>
#       2 patient_ref = db.collection("patients").limit(10).where('gender', '==', 'M').where('email', '<', 'f')
#       3 docs = patient_ref.stream()
# ----> 4 print_docs(docs)
#
# <ipython-input-4-b395b0600dd4> in print_docs(docs)
#       5
#       6 def print_docs(docs):
# ----> 7     for doc in docs:
#       8         print_doc(doc)
#       9
#
# ~/anaconda3/lib/python3.6/site-packages/google/cloud/firestore_v1/query.py in stream(self, transaction)
#     739         )
#     740
# --> 741         for response in response_iterator:
#     742             snapshot = _query_response_to_snapshot(
#     743                 response, self._parent, expected_prefix
#
# ~/anaconda3/lib/python3.6/site-packages/google/api_core/grpc_helpers.py in next(self)
#      79             return six.next(self._wrapped)
#      80         except grpc.RpcError as exc:
# ---> 81             six.raise_from(exceptions.from_grpc_error(exc), exc)
#      82
#      83     # Alias needed for Python 2/3 support.
#
# ~/anaconda3/lib/python3.6/site-packages/six.py in raise_from(value, from_value)
#
# FailedPrecondition: 400 The query requires an index. You can create it here: https://console.firebase.google.com/project/dmd-hospital-system/database/firestore/indexes?create_composite=ClRwcm9qZWN0cy9kbWQtaG9zcGl0YWwtc3lzdGVtL2RhdGFiYXNlcy8oZGVmYXVsdCkvY29sbGVjdGlvbkdyb3Vwcy9wYXRpZW50cy9pbmRleGVzL18QARoKCgZnZW5kZXIQARoJCgVlbWFpbBABGgwKCF9fbmFtZV9fEAE

# %%
patient_ref = db.collection("patients").limit(10).where('gender', '==', 'M').where('name', '<', 'F')
docs = patient_ref.stream()
print_docs(docs)
# Out:
#                                                      address  contactNumber  \
# WxaM7w7QbebYmIllMDr0  587 Jamie Club\nKristinmouth, MS 24890  (208)323-9419
#
#                                          email gender  \
# WxaM7w7QbebYmIllMDr0  cynthiabonilla@yahoo.com      M
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  medHistory  \
# WxaM7w7QbebYmIllMDr0  [{'date': 2018-02-20 14:23:27+00:00, 'note': 'Year beat account agree. Brother later green fear tonight. Analysis bar campaign. Law thousand recently prove if recently pattern.', 'prescription': None}, {'date': 2018-08-10 05:14:07+00:00, 'note': 'Over eye including impact why couple work share. Nice citizen what education prevent happy. Court general actually tax area wait score.', 'prescription': None}, {'note': 'Catch within foot type what bill suddenly court. Former recent skin plant wife federal meet.', 'date': 2018-01-21 09:51:45+00:00, 'prescription': None}, {'prescription': None, 'note': 'Matter magazine staff resource admit out. Street floor late.', 'date': 2018-08-31 22:58:41+00:00}, {'prescription': None, 'note': 'Realize realize nation kind people spring. Need goal box break century the. Gas argue third enough teach explain.', 'date': 2018-09-29 15:44:16+00:00}]
#
#                              name
# WxaM7w7QbebYmIllMDr0  Aaron Adams
#                                                                address  \
# hZxtXKtXMva68qaa6uoU  5961 Nathan Forest Apt. 199\nEast Jeff, OK 76694
#
#                      contactNumber                   email gender  \
# hZxtXKtXMva68qaa6uoU    2509885824  karahunter@hotmail.com      M
#
#                                                                                                                                                                                                                                                                                                                                                               medHistory  \
# hZxtXKtXMva68qaa6uoU  [{'prescription': None, 'note': 'Shoulder lot church environment could whole feel even. Across rather federal.', 'date': 2018-03-11 08:07:47+00:00}, {'date': 2018-03-15 10:28:39+00:00, 'note': 'Effect figure church under resource include. These hour ability worker. Notice must shoulder stage style group popular.', 'prescription': None}]
#
#                              name
# hZxtXKtXMva68qaa6uoU  Aaron Bruce
#                                                       address  \
# 5pNeH2boCA7FOBy4aQeS  9292 Chapman Points\nPaulbury, WV 85797
#
#                            contactNumber                         email gender  \
# 5pNeH2boCA7FOBy4aQeS  348-105-1669x80376  brittanyphillips@hotmail.com      M
#
#                                                                                                                                                                                                                                                                                                      medHistory  \
# 5pNeH2boCA7FOBy4aQeS  [{'prescription': None, 'date': 2018-03-20 22:21:29+00:00, 'note': 'Art seat myself why next occur focus. Beyond tree current probably.'}, {'date': 2018-01-21 18:25:02+00:00, 'note': 'What expect address during group the. Area federal future school simply.', 'prescription': None}]
#
#                                     name
# 5pNeH2boCA7FOBy4aQeS  Aaron Harrison DVM
#                                                   address  \
# 05BE3yqF940dy5og1dM6  704 Brown Crest\nMaysport, WI 60514
#
#                              contactNumber                  email gender  \
# 05BE3yqF940dy5og1dM6  +1-648-565-2726x8569  hsantiago@hotmail.com      M
#
#                                                                                                                                                                                                                                     medHistory  \
# 05BE3yqF940dy5og1dM6  [{'note': 'Low voice imagine general shoulder offer. Stay environment this mouth somebody performance grow. Same order want door challenge indicate nothing.', 'date': 2018-12-17 11:36:20+00:00, 'prescription': None}]
#
#                             name
# 05BE3yqF940dy5og1dM6  Alan Allen
#                                                                      address  \
# y6KpnHveb93ABBStYigG  36491 Courtney Heights Apt. 932\nJustinshire, NM 79001
#
#                       contactNumber            email gender  \
# y6KpnHveb93ABBStYigG  (198)201-1486  qbell@gmail.com      M
#
#                                                                                                                                                                                            medHistory  \
# y6KpnHveb93ABBStYigG  [{'note': 'Democrat face parent father chair dinner. Least whom six team chair adult girl. Research happy movement.', 'date': 2018-05-19 10:01:03+00:00, 'prescription': None}]
#
#                               name
# y6KpnHveb93ABBStYigG  Alan Maynard
#                                                                     address  \
# s2RcamDc74SR4w0g6jNT  36903 Gomez Forges Suite 251\nWest Michelle, MS 04450
#
#                          contactNumber                    email gender  \
# s2RcamDc74SR4w0g6jNT  645-780-9703x074  kathrynfuller@gmail.com      M
#
#                      medHistory              name
# s2RcamDc74SR4w0g6jNT         []  Alejandro Flores
#                                                                     address  \
# 05vu7nfTWREh86oTrnSR  63341 Perkins Estate Suite 820\nLowerymouth, NH 93567
#
#                                contactNumber              email gender  \
# 05vu7nfTWREh86oTrnSR  001-561-060-2677x97244  xjordan@gmail.com      M
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    medHistory  \
# 05vu7nfTWREh86oTrnSR  [{'prescription': None, 'date': 2018-12-16 23:11:02+00:00, 'note': 'Mouth grow finally suggest shoulder president. Key life body population test American. Spend protect today risk other.'}, {'prescription': None, 'note': 'Design individual strong fact.', 'date': 2018-08-29 11:42:39+00:00}, {'date': 2018-09-01 04:36:44+00:00, 'note': 'Leg these best agency must partner hope nation. Time smile challenge north gas himself office.', 'prescription': None}]
#
#                               name
# 05vu7nfTWREh86oTrnSR  Alex Cabrera
#                                                        address contactNumber  \
# kswWY2dxagJwe4vb3LOl  66447 Joshua Estate\nRobertton, MS 12779  529.414.6930
#
#                                           email gender  \
# kswWY2dxagJwe4vb3LOl  brittneyblack@hotmail.com      M
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               medHistory  \
# kswWY2dxagJwe4vb3LOl  [{'date': 2018-07-26 16:26:14+00:00, 'note': 'Soon decide forget fire drive. Avoid often single century rich food.', 'prescription': None}, {'note': 'Agree wrong believe mouth phone teacher. Bit and professional fall art store. Relationship great opportunity level their woman course.', 'date': 2018-05-22 15:38:26+00:00, 'prescription': None}, {'date': 2018-04-13 19:40:13+00:00, 'note': 'Big break third several evidence. Southern similar by in. Everybody win church more worker fire campaign. Build fear determine never personal fund.', 'prescription': None}]
#
#                                   name
# kswWY2dxagJwe4vb3LOl  Alexander Booker
#                                                                        address  \
# LXMda8fpRPGAFiEqeFo8  37177 Mcdonald Club Apt. 498\nNew Annettehaven, NE 62292
#
#                              contactNumber                    email gender  \
# LXMda8fpRPGAFiEqeFo8  +1-932-884-9741x1606  craigwarren@hotmail.com      M
#
#                      medHistory             name
# LXMda8fpRPGAFiEqeFo8         []  Alexander Payne
#                                                        address  contactNumber  \
# tNjEgXWrdLR5k33CXWGr  75862 Lewis Forks\nNorth David, VA 80183  (434)335-3168
#
#                                        email gender medHistory  \
# tNjEgXWrdLR5k33CXWGr  dianabernard@gmail.com      M         []
#
#                                    name
# tNjEgXWrdLR5k33CXWGr  Alexander Sanchez

# %% [markdown]
# You can only perform range comparisons (<, <=, >, >=) on a single field, and you can include at most one array_contains clause in a compound query:

# %%
ref = db.collection("employees").limit(10).where('salary', '>=', 8000).where('salary', '<=', 12000)
docs = ref.stream()
print_docs(docs)
# Out:
#                                                       address  \
# Pm3VMtuCWcL7ZjgF2zwc  97652 Ramos Pass\nBennettview, OH 73915
#
#                               contactNumber gender            name    role  \
# Pm3VMtuCWcL7ZjgF2zwc  +1-872-556-4806x34906      F  Lindsay Brooks  doctor
#
#                       salary     status
# Pm3VMtuCWcL7ZjgF2zwc   12000  permanent
#                                                                    address  \
# twJavXXAozUIWiT4s02c  8354 Johnson Islands Apt. 758\nEast Steven, KY 41861
#
#                           contactNumber gender           name        role  \
# twJavXXAozUIWiT4s02c  960-989-0733x2729      F  Lauren Valdez  pharmacist
#
#                       salary
# twJavXXAozUIWiT4s02c   12000

# %%
# P.S. it should fail
ref = db.collection("employees").where('salary', '>=', 14000).where('name', '>=', 'T')
docs = ref.stream()
print_docs(docs)
# Out:
# ---------------------------------------------------------------------------
# _Rendezvous                               Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/google/api_core/grpc_helpers.py in next(self)
#      78         try:
# ---> 79             return six.next(self._wrapped)
#      80         except grpc.RpcError as exc:
#
# ~/anaconda3/lib/python3.6/site-packages/grpc/_channel.py in __next__(self)
#     362     def __next__(self):
# --> 363         return self._next()
#     364
#
# ~/anaconda3/lib/python3.6/site-packages/grpc/_channel.py in _next(self)
#     356                     elif self._state.code is not None:
# --> 357                         raise self
#     358
#
# _Rendezvous: <_Rendezvous of RPC that terminated with:
# 	status = StatusCode.INVALID_ARGUMENT
# 	details = "Cannot have inequality filters on multiple properties: [name, salary]"
# 	debug_error_string = "{"created":"@1556190700.451423036","description":"Error received from peer ipv4:173.194.73.95:443","file":"src/core/lib/surface/call.cc","file_line":1041,"grpc_message":"Cannot have inequality filters on multiple properties: [name, salary]","grpc_status":3}"
# >
#
# The above exception was the direct cause of the following exception:
#
# InvalidArgument                           Traceback (most recent call last)
# <ipython-input-24-a337dfa17c45> in <module>
#       2 ref = db.collection("employees").where('salary', '>=', 14000).where('name', '>=', 'T')
#       3 docs = ref.stream()
# ----> 4 print_docs(docs)
#
# <ipython-input-4-b395b0600dd4> in print_docs(docs)
#       5
#       6 def print_docs(docs):
# ----> 7     for doc in docs:
#       8         print_doc(doc)
#       9
#
# ~/anaconda3/lib/python3.6/site-packages/google/cloud/firestore_v1/query.py in stream(self, transaction)
#     739         )
#     740
# --> 741         for response in response_iterator:
#     742             snapshot = _query_response_to_snapshot(
#     743                 response, self._parent, expected_prefix
#
# ~/anaconda3/lib/python3.6/site-packages/google/api_core/grpc_helpers.py in next(self)
#      79             return six.next(self._wrapped)
#      80         except grpc.RpcError as exc:
# ---> 81             six.raise_from(exceptions.from_grpc_error(exc), exc)
#      82
#      83     # Alias needed for Python 2/3 support.
#
# ~/anaconda3/lib/python3.6/site-packages/six.py in raise_from(value, from_value)
#
# InvalidArgument: 400 Cannot have inequality filters on multiple properties: [name, salary]

# %% [markdown]
# ### let's make a multiple join query
#
#     SELECT nurse FROM patients AS pat
#              JOIN room_assignment AS asn ON pat=asn.patient
#              JOIN room AS r ON asn.room=r
#              JOIN employees AS nurse ON r.nurse=nurse
#              WHERE pat.gender='M' LIMIT 10

# %%
def operation():
    # get patients
    query1 = db.collection('patients').limit(10).where('gender', '==', 'M')
    patients = query1.stream()
    for pat in patients:
        # for each patient get its room_assignments
        query2 = db.collection('room_assignment').where('patient', '==', pat.reference)
        assigns = query2.stream()
        for asn in assigns:
            # take a room from the room_assignment
            room_ref = asn.to_dict()['room']
            room_doc = room_ref.get()
            # take a nurse governing this room
            nurse_ref = room_doc.to_dict()['nurse']
            nurse_doc = nurse_ref.get()
            print_doc(nurse_doc)
operation()
# Out:
#                                                            address  \
# Q1K88a2QmoX64mQyy1Fm  9582 Kaiser Harbor\nPattersonshire, SC 66561
#
#                             contactNumber gender               name   role  \
# Q1K88a2QmoX64mQyy1Fm  (621)970-6812x88214      F  Dr. Deborah Smith  nurse
#
#                       salary
# Q1K88a2QmoX64mQyy1Fm   20450
#                                                          address  \
# 2Z0zaQD6TCyxU2CQRU5x  8875 William Canyon\nWest Carrie, TX 61859
#
#                      contactNumber gender             name   role  salary
# 2Z0zaQD6TCyxU2CQRU5x    4036207785      M  Justin Harrison  nurse   29850
#                                                                     address  \
# e31Kq3SqiBXwPSvCdJPs  89102 Ryan Throughway Apt. 948\nLake Marvin, ID 44283
#
#                          contactNumber gender           name   role  salary
# e31Kq3SqiBXwPSvCdJPs  774.966.0930x304      M  Jordan Murphy  nurse   17810
